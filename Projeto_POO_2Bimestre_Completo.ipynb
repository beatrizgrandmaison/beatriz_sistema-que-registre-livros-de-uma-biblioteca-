# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Definindo a classe Livro
class Livro:
    # Construtor para inicializar os atributos do livro
    def __init__(self, titulo, autor, ano_publicacao):
        self.titulo = titulo
        self.autor = autor
        self.ano_publicacao = ano_publicacao

    # Método para exibir informações sobre o livro
    def exibir_dados(self):
        print(f"Título: {self.titulo}")
        print(f"Autor: {self.autor}")
        print(f"Ano de Publicação: {self.ano_publicacao}")
        print("-" * 30)

# Criando dois objetos da classe Livro
livro1 = Livro("1984", "George Orwell", 1949)
livro2 = Livro("Dom Casmurro", "Machado de Assis", 1899)

# Exibindo os dados dos livros
livro1.exibir_dados()
livro2.exibir_dados()
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/beatriz_grandmaison/AppData/Local/Microsoft/WindowsApps/python3.11.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Classe Livro com métodos adicionais
class Livro:
    # Construtor para inicializar os atributos do livro
    def __init__(self, titulo, autor, ano_publicacao):
        self.titulo = titulo
        self.autor = autor
        self.ano_publicacao = ano_publicacao
        self.emprestado = False  # Atributo para verificar se o livro está emprestado

    # Método para exibir informações sobre o livro
    def exibir_dados(self):
        print(f"Título: {self.titulo}")
        print(f"Autor: {self.autor}")
        print(f"Ano de Publicação: {self.ano_publicacao}")
        print(f"Emprestado: {'Sim' if self.emprestado else 'Não'}")
        print("-" * 30)
    
    # Método para marcar o livro como emprestado
    def emprestar(self):
        if not self.emprestado:
            self.emprestado = True
            print(f"O livro '{self.titulo}' foi emprestado.")
        else:
            print(f"O livro '{self.titulo}' já está emprestado.")

    # Método para devolver o livro
    def devolver(self):
        if self.emprestado:
            self.emprestado = False
            print(f"O livro '{self.titulo}' foi devolvido.")
        else:
            print(f"O livro '{self.titulo}' não estava emprestado.")

# Subclasse LivroDigital, herdando de Livro
class LivroDigital(Livro):
    def __init__(self, titulo, autor, ano_publicacao, formato_arquivo):
        # Usando super() para inicializar a parte da classe pai
        super().__init__(titulo, autor, ano_publicacao)
        self.formato_arquivo = formato_arquivo  # Novo atributo exclusivo para livros digitais

    # Método exclusivo da subclasse para exibir o formato do arquivo
    def exibir_formato(self):
        print(f"Formato do Arquivo: {self.formato_arquivo}")
        print("-" * 30)

# Criando objetos da classe Livro e LivroDigital
livro1 = Livro("1984", "George Orwell", 1949)
livro2 = Livro("Dom Casmurro", "Machado de Assis", 1899)
livro_digital = LivroDigital("Python para Iniciantes", "João Silva", 2021, "PDF")

# Exibindo dados dos livros
livro1.exibir_dados()
livro2.exibir_dados()

# Usando os métodos de ação
livro1.emprestar()  # Emprestando livro1
livro2.devolver()   # Tentando devolver livro2 (não emprestado)

# Exibindo dados do livro digital
livro_digital.exibir_dados()  # Exibindo dados do livro digital
livro_digital.exibir_formato()  # Exibindo o formato do arquivo

# Emprestando e devolvendo o livro digital
livro_digital.emprestar()  # Emprestando livro digital
livro_digital.devolver()   # Devolvendo livro digital
# Out:
# Título: 1984
# Autor: George Orwell
# Ano de Publicação: 1949
# Emprestado: Não
# ------------------------------
# Título: Dom Casmurro
# Autor: Machado de Assis
# Ano de Publicação: 1899
# Emprestado: Não
# ------------------------------
# O livro '1984' foi emprestado.
# O livro 'Dom Casmurro' não estava emprestado.
# Título: Python para Iniciantes
# Autor: João Silva
# Ano de Publicação: 2021
# Emprestado: Não
# ------------------------------
# Formato do Arquivo: PDF
# ------------------------------
# O livro 'Python para Iniciantes' foi emprestado.
# O livro 'Python para Iniciantes' foi devolvido.

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Classe Livro com encapsulamento e abstração
class Livro:
    def __init__(self, titulo, autor, ano_publicacao, preco):
        self.titulo = titulo
        self.autor = autor
        self.ano_publicacao = ano_publicacao
        self.__preco = preco  # Atributo privado

    # Método para exibir informações sobre o livro
    def exibir_dados(self):
        print(f"Título: {self.titulo}")
        print(f"Autor: {self.autor}")
        print(f"Ano de Publicação: {self.ano_publicacao}")
        print(f"Preço: R${self.get_preco():.2f}")
        print("-" * 30)
    
    # Método de ação para emprestar o livro
    def emprestar(self):
        print(f"O livro '{self.titulo}' foi emprestado.")

    # Método para calcular o preço com um desconto (lógica interna)
    def aplicar_desconto(self, percentual_desconto):
        if percentual_desconto < 0 or percentual_desconto > 100:
            print("Percentual de desconto inválido!")
        else:
            desconto = (self.__preco * percentual_desconto) / 100
            novo_preco = self.__preco - desconto
            print(f"Novo preço do livro '{self.titulo}' após {percentual_desconto}% de desconto: R${novo_preco:.2f}")
            self.__preco = novo_preco

    # Método get para acessar o atributo privado __preco
    def get_preco(self):
        return self.__preco

    # Método set para alterar o valor do atributo privado __preco
    def set_preco(self, novo_preco):
        if novo_preco < 0:
            print("Preço não pode ser negativo!")
        else:
            self.__preco = novo_preco
            print(f"Preço do livro '{self.titulo}' alterado para R${novo_preco:.2f}")

# Subclasse LivroDigital
class LivroDigital(Livro):
    def __init__(self, titulo, autor, ano_publicacao, preco, formato_arquivo):
        super().__init__(titulo, autor, ano_publicacao, preco)
        self.formato_arquivo = formato_arquivo

    def exibir_formato(self):
        print(f"Formato do Arquivo: {self.formato_arquivo}")
        print("-" * 30)

# Criando objetos
livro1 = Livro("1984", "George Orwell", 1949, 39.90)
livro2 = Livro("Dom Casmurro", "Machado de Assis", 1899, 29.90)
livro_digital = LivroDigital("Python para Iniciantes", "João Silva", 2021, 49.90, "PDF")

# Exibindo dados dos livros
livro1.exibir_dados()
livro2.exibir_dados()

# Aplicando desconto no livro
livro1.aplicar_desconto(10)  # Aplicando 10% de desconto no preço do livro

# Alterando o preço do livro diretamente com o método set
livro2.set_preco(25.00)  # Alterando o preço para R$25.00

# Exibindo novamente os dados após alterações
livro1.exibir_dados()
livro2.exibir_dados()

# Exibindo dados do livro digital
livro_digital.exibir_dados()  # Exibindo os dados do livro digital
livro_digital.exibir_formato()  # Exibindo o formato do arquivo
# Out:
# Título: 1984
# Autor: George Orwell
# Ano de Publicação: 1949
# Preço: R$39.90
# ------------------------------
# Título: Dom Casmurro
# Autor: Machado de Assis
# Ano de Publicação: 1899
# Preço: R$29.90
# ------------------------------
# Novo preço do livro '1984' após 10% de desconto: R$35.91
# Preço do livro 'Dom Casmurro' alterado para R$25.00
# Título: 1984
# Autor: George Orwell
# Ano de Publicação: 1949
# Preço: R$35.91
# ------------------------------
# Título: Dom Casmurro
# Autor: Machado de Assis
# Ano de Publicação: 1899
# Preço: R$25.00
# ------------------------------
# Título: Python para Iniciantes
# Autor: João Silva
# Ano de Publicação: 2021
# Preço: R$49.90
# ------------------------------
# Formato do Arquivo: PDF
# ------------------------------

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

# Classe base
class Livro:
    def __init__(self, titulo, autor):
        self.titulo = titulo
        self.autor = autor

    def descricao(self):
        return f"Livro físico: '{self.titulo}' de {self.autor}"


# Subclasse com polimorfismo (sobrescreve o método descricao)
class LivroDigital(Livro):
    def __init__(self, titulo, autor, formato):
        super().__init__(titulo, autor)
        self.formato = formato

    def descricao(self):
        return f"Livro digital: '{self.titulo}' de {self.autor} (formato: {self.formato})"


# Classe de gerenciamento do banco de dados
class BibliotecaDB:
    def __init__(self, nome_banco="biblioteca.db"):
        self.conexao = sqlite3.connect(nome_banco)
        self.criar_tabela()

    def criar_tabela(self):
        cursor = self.conexao.cursor()
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS livros (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                titulo TEXT NOT NULL,
                autor TEXT NOT NULL,
                tipo TEXT NOT NULL,
                formato TEXT
            )
        ''')
        self.conexao.commit()

    def inserir_livro(self, livro):
        cursor = self.conexao.cursor()
        tipo = "Digital" if isinstance(livro, LivroDigital) else "Físico"
        formato = livro.formato if isinstance(livro, LivroDigital) else None
        cursor.execute('''
            INSERT INTO livros (titulo, autor, tipo, formato) VALUES (?, ?, ?, ?)
        ''', (livro.titulo, livro.autor, tipo, formato))
        self.conexao.commit()

    def listar_livros(self):
        cursor = self.conexao.cursor()
        cursor.execute('SELECT id, titulo, autor, tipo, formato FROM livros')
        return cursor.fetchall()

    def deletar_livro(self, livro_id):
        cursor = self.conexao.cursor()
        cursor.execute('DELETE FROM livros WHERE id = ?', (livro_id,))
        self.conexao.commit()

    def fechar(self):
        self.conexao.close()


# Exemplo de uso
if __name__ == "__main__":
    db = BibliotecaDB()

    # Criando livros
    livro1 = Livro("O Senhor dos Anéis", "J.R.R. Tolkien")
    livro2 = LivroDigital("1984", "George Orwell", "PDF")

    # Inserindo no banco
    db.inserir_livro(livro1)
    db.inserir_livro(livro2)

    # Listando livros
    livros = db.listar_livros()
    print("Livros cadastrados no banco:")
    for l in livros:
        print(l)

    # Excluindo um livro (exemplo com ID 1)
    # db.deletar_livro(1)

    db.fechar()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3

# ==============================
# CLASSES - ORIENTAÇÃO A OBJETOS
# ==============================

# Classe base que representa um livro físico
class Livro:
    def __init__(self, titulo, autor):
        self.titulo = titulo
        self.autor = autor

    def descricao(self):
        return f"Livro físico: '{self.titulo}' de {self.autor}"


# Subclasse que representa um livro digital, herda de Livro
# Aplica polimorfismo ao sobrescrever o método descricao()
class LivroDigital(Livro):
    def __init__(self, titulo, autor, formato):
        super().__init__(titulo, autor)
        self.formato = formato

    def descricao(self):
        return f"Livro digital: '{self.titulo}' de {self.autor} (formato: {self.formato})"


# ========================================
# BANCO DE DADOS - CRUD com SQLite
# ========================================

class BibliotecaDB:
    def __init__(self, nome_banco="biblioteca.db"):
        # Conecta (ou cria) o banco de dados SQLite
        self.conexao = sqlite3.connect(nome_banco)
        self.criar_tabela()

    def criar_tabela(self):
        # Cria a tabela "livros" caso não exista
        cursor = self.conexao.cursor()
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS livros (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                titulo TEXT NOT NULL,
                autor TEXT NOT NULL,
                tipo TEXT NOT NULL,
                formato TEXT
            )
        ''')
        self.conexao.commit()

    def inserir_livro(self, livro):
        # Insere um livro no banco (físico ou digital)
        cursor = self.conexao.cursor()
        tipo = "Digital" if isinstance(livro, LivroDigital) else "Físico"
        formato = livro.formato if isinstance(livro, LivroDigital) else None
        cursor.execute('''
            INSERT INTO livros (titulo, autor, tipo, formato) VALUES (?, ?, ?, ?)
        ''', (livro.titulo, livro.autor, tipo, formato))
        self.conexao.commit()

    def listar_livros(self):
        # Retorna todos os livros cadastrados
        cursor = self.conexao.cursor()
        cursor.execute('SELECT id, titulo, autor, tipo, formato FROM livros')
        return cursor.fetchall()

    def deletar_livro(self, livro_id):
        # Remove um livro pelo ID
        cursor = self.conexao.cursor()
        cursor.execute('DELETE FROM livros WHERE id = ?', (livro_id,))
        self.conexao.commit()

    def fechar(self):
        # Encerra a conexão com o banco
        self.conexao.close()


# ========================
# TESTES DAS FUNCIONALIDADES
# ========================

def main():
    # Instancia o banco de dados
    db = BibliotecaDB()

    # Cria alguns livros
    livro1 = Livro("Dom Casmurro", "Machado de Assis")
    livro2 = LivroDigital("Python para Iniciantes", "Maria Silva", "ePub")
    livro3 = LivroDigital("O Pequeno Príncipe", "Antoine de Saint-Exupéry", "PDF")

    # Insere os livros no banco
    db.inserir_livro(livro1)
    db.inserir_livro(livro2)
    db.inserir_livro(livro3)

    # Lista os livros cadastrados
    print("\n📚 LIVROS CADASTRADOS:")
    for livro in db.listar_livros():
        print(f"ID {livro[0]} - {livro[1]} de {livro[2]} [{livro[3]}]")

    # Exemplo de exclusão (descomente para testar)
    # db.deletar_livro(1)

    # Fecha conexão com o banco
    db.fechar()


# Executa o script principal
if __name__ == "__main__":
    main()
